# %%
print("Jai Ganesh")
# Out:
# Jai Ganesh

# %% [markdown]
# ## Map Function

# %%
# Syntax: map(function, iterable)

# %%
def cube(n):
    list1=[]
    for i in n:
        list1.append(i**3)
    return list1

values=[2,3,4,5,6]
result=cube(values)
print(result)
# Out:
# [8, 27, 64, 125, 216]
